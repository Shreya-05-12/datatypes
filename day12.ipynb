# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df=sns.load_dataset('taxis')

# %%
df
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment            pickup_zone  \
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
# ...

# %%
df.sample(5) #any 5 randomly
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 549  2019-03-16 22:51:55 2019-03-16 23:17:51           1      3.29  17.5
# 451  2019-03-06 08:38:24 2019-03-06 08:57:53           1      1.26  12.5
# 5846 2019-03-15 21:31:51 2019-03-15 21:50:02           1      2.90  13.5
# 2889 2019-03-28 20:44:04 2019-03-28 21:00:46           2      2.70  13.5
# 842  2019-03-29 10:36:53 2019-03-29 10:48:38           1      1.19   8.5
#
#        tip  tolls  total   color      payment                pickup_zone  \
# 549   5.32    0.0  26.62  yellow  credit card            Lower East Side
# 451   0.00    0.0  15.80  yellow         cash           Garment District
# 5846  0.00    0.0  14.80   green         cash                   Elmhurst
# 2889  0.00    0.0  17.30  yellow         cash  West Chelsea/Hudson Yards
# 842   2.36    0.0  14.16  yellow  credit card               West Village
#
#        dropoff_zone pickup_borough dropoff_borough
# ...

# %%
df.tail(10) #last 10
# Out:
#                   pickup             dropoff  passengers  distance   fare  \
# 6423 2019-03-12 08:10:47 2019-03-12 08:35:35           1      4.30  18.50
# 6424 2019-03-30 20:52:15 2019-03-30 20:59:55           1      1.70   8.00
# 6425 2019-03-07 15:34:30 2019-03-07 16:31:06           1      9.12  26.32
# 6426 2019-03-28 08:04:47 2019-03-28 08:07:46           1      0.71   4.50
# 6427 2019-03-23 18:26:09 2019-03-23 18:49:12           1      7.07  20.00
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.50
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.00
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.00
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.00
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.00
#
#        tip  tolls  total  color      payment          pickup_zone  \
# 6423  0.00    0.0  19.30  green  credit card         Saint Albans
# ...

# %%
df.head(10) #first 10
# Out:
#                pickup             dropoff  passengers  distance  fare   tip  \
# 0 2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0  2.15
# 1 2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0  0.00
# 2 2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5  2.36
# 3 2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0  6.15
# 4 2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0  1.10
# 5 2019-03-11 10:37:23 2019-03-11 10:47:31           1      0.49   7.5  2.16
# 6 2019-03-26 21:07:31 2019-03-26 21:17:29           1      3.65  13.0  2.00
# 7 2019-03-22 12:47:13 2019-03-22 12:58:17           0      1.40   8.5  0.00
# 8 2019-03-23 11:48:50 2019-03-23 12:06:14           1      3.63  15.0  1.00
# 9 2019-03-08 16:18:37 2019-03-08 16:26:57           1      1.52   8.0  1.00
#
#    tolls  total   color      payment                pickup_zone  \
# 0    0.0  12.95  yellow  credit card            Lenox Hill West
# ...

# %%
df['color'].isnull() #whether iit is null or not ,if it is empty only it will give true
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 6428    False
# 6429    False
# 6430    False
# 6431    False
# 6432    False
# Name: color, Length: 6433, dtype: bool

# %%
df['color'].isnull().sum() #no.of missing values
# Out:
# 0

# %%
df['payment'].isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 6428    False
# 6429    False
# 6430    False
# 6431    False
# 6432    False
# Name: payment, Length: 6433, dtype: bool

# %%
df['payment'].isnull().sum()
# Out:
# 44

# %%
df.isnull().sum() #no of missing values
# Out:
# pickup              0
# dropoff             0
# passengers          0
# distance            0
# fare                0
# tip                 0
# tolls               0
# total               0
# color               0
# payment            44
# pickup_zone        26
# dropoff_zone       45
# pickup_borough     26
# dropoff_borough    45
# dtype: int64

# %%
(26/6433)*100
# Out:
# 0.4041660189647132

# %%
df.shape[0] #no.of rows
# Out:
# 6433

# %%
(df.isnull().sum()/df.shape[0])*100
# Out:
# pickup             0.000000
# dropoff            0.000000
# passengers         0.000000
# distance           0.000000
# fare               0.000000
# tip                0.000000
# tolls              0.000000
# total              0.000000
# color              0.000000
# payment            0.683973
# pickup_zone        0.404166
# dropoff_zone       0.699518
# pickup_borough     0.404166
# dropoff_borough    0.699518
# dtype: float64

# %%
''' missing data handling
1) Imputation (fill in the blanks)
    1. statistical measures
    2. parameters
2) delete data
    1. rows
    2. columns'''
# Out:
# ' missing data handling\n1) Imputation (fill in the blanks)\n    1. statistical measures\n    2. parameters\n2) delete data\n    1. rows\n    2. columns'

# %%
df.drop('pickup_zone',axis=1) #to delete column
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment  \
# ...

# %%
df
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment            pickup_zone  \
# ...

# %%
# if we want to delete column permanently we use inplace()
df.drop('pickup_zone',axis=1,inplace=True)
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[59], line 2
#       1 # if we want to delete column permanently we use inplace()
# ----> 2 df.drop('pickup_zone',axis=1,inplace=True)
#       3 df
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
# ...

# %%
df.drop([2,3,6430,6432],axis=0,inplace=True)

# %%
a=np.random.randint(10,50,15)
a
# Out:
# array([27, 36, 29, 15, 23, 38, 36, 25, 44, 17, 22, 13, 43, 14, 14])

# %%
a[a>40]
# Out:
# array([44, 43])

# %%
df[df['color']=='yellow']
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# 5    2019-03-11 10:37:23 2019-03-11 10:47:31           1      0.49   7.5
# 6    2019-03-26 21:07:31 2019-03-26 21:17:29           1      3.65  13.0
# ...                  ...                 ...         ...       ...   ...
# 5446 2019-03-11 21:19:42 2019-03-11 21:29:23           1      2.09   9.5
# 5447 2019-03-20 18:09:46 2019-03-20 18:16:52           1      1.52   7.5
# 5448 2019-03-09 11:08:09 2019-03-09 11:18:03           1      2.05   9.5
# 5449 2019-03-22 18:12:50 2019-03-22 18:22:05           1      1.07   7.5
# 5450 2019-03-07 18:02:33 2019-03-07 18:13:32           1      1.80   9.0
#
#        tip  tolls  total   color      payment                pickup_zone  \
# ...

# %%
df[df['total']>15]
# Out:
#                   pickup             dropoff  passengers  distance   fare  \
# 6    2019-03-26 21:07:31 2019-03-26 21:17:29           1      3.65  13.00
# 8    2019-03-23 11:48:50 2019-03-23 12:06:14           1      3.63  15.00
# 10   2019-03-16 10:02:25 2019-03-16 10:22:29           1      3.90  17.00
# 15   2019-03-16 17:53:34 2019-03-16 18:13:57           3      2.09  13.50
# 16   2019-03-15 12:36:05 2019-03-15 12:54:28           1      2.12  13.00
# ...                  ...                 ...         ...       ...    ...
# 6422 2019-03-22 20:17:35 2019-03-22 20:36:07           1      4.02  16.00
# 6423 2019-03-12 08:10:47 2019-03-12 08:35:35           1      4.30  18.50
# 6425 2019-03-07 15:34:30 2019-03-07 16:31:06           1      9.12  26.32
# 6427 2019-03-23 18:26:09 2019-03-23 18:49:12           1      7.07  20.00
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.00
#
#       tip  tolls  total   color      payment               pickup_zone  \
# ...

# %%
df['payment']=='cash'
# Out:
# 0       False
# 1        True
# 4       False
# 5       False
# 6       False
#         ...
# 6426    False
# 6427     True
# 6428    False
# 6429    False
# 6431    False
# Name: payment, Length: 6429, dtype: bool

# %%
df[(df['payment']=='cash')&(df['total']>15)]
# Out:
#                   pickup             dropoff  passengers  distance  fare  tip  \
# 10   2019-03-16 10:02:25 2019-03-16 10:22:29           1      3.90  17.0  0.0
# 15   2019-03-16 17:53:34 2019-03-16 18:13:57           3      2.09  13.5  0.0
# 16   2019-03-15 12:36:05 2019-03-15 12:54:28           1      2.12  13.0  0.0
# 26   2019-03-03 02:45:36 2019-03-03 03:02:14           1      3.35  13.5  0.0
# 29   2019-03-06 08:09:03 2019-03-06 08:27:11           1      0.92  12.0  0.0
# ...                  ...                 ...         ...       ...   ...  ...
# 6405 2019-03-21 18:28:55 2019-03-21 18:51:08           2      3.88  16.5  0.0
# 6407 2019-03-07 16:35:42 2019-03-07 16:50:03           1      2.68  12.0  0.0
# 6408 2019-03-04 07:27:58 2019-03-04 07:49:25           1      6.48  22.0  0.0
# 6422 2019-03-22 20:17:35 2019-03-22 20:36:07           1      4.02  16.0  0.0
# 6427 2019-03-23 18:26:09 2019-03-23 18:49:12           1      7.07  20.0  0.0
#
# ...
